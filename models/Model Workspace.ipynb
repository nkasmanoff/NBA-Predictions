# %% [markdown]
# # This notebook serves a workspace where I am in the process of implementing different machine learning algorithms to the dataset I created in the previous repository, and works to make one that earns the most $

# %%
import pandas as pd

# %%
data = pd.read_csv('../splits_optimizer/model_ready_data.csv')

# %%
data
# Out:
#       Unnamed: 0  road_Rolling FG  road_Rolling 3P  road_Rolling FT  \
# 0              0        41.033333         8.966667        17.366667
# 1              1        35.633333         6.366667        15.600000
# 2              2        39.466667         8.533333        16.466667
# 3              3        34.866667         5.033333        18.500000
# 4              4        39.000000         9.566667        15.866667
# 5              5        38.533333         9.233333        15.700000
# 6              6        34.800000         7.466667        19.900000
# 7              7        40.166667        10.400000        18.433333
# 8              8        34.800000         7.066667        16.000000
# 9              9        39.500000         7.500000        16.166667
# 10            10        34.800000         5.166667        18.166667
# 11            11        36.966667         7.333333        15.966667
# 12            12        38.600000         9.066667        15.600000
# ...
