# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
data = pd.read_csv('spread2ML.csv')

# %%
x = data['Spread'].values

# %%
y = data['ML'].values

# %%
plt.style.use('fivethirtyeight')
plt.legend()
plt.xlabel("Spread")
plt.ylabel("Moneyline")
plt.title("Approximation of Spread to Moneyline Odds for NBA Games")

plt.plot(data['Spread'],data['ML'],'.',label='actual')
# Out:
# /Users/noahkasmanoff/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
negatives = data.head(n=21)

# %%
fit
# Out:
# array([   1.71409498,   10.90008433,   22.40247106, -138.20112341])

# %%
xneg = negatives['Spread'].values
yneg = negatives['ML'].values

fit = np.polyfit(xneg,yneg,3)


xfit = np.linspace(-10,1,100)

yfit = []
for x in xfit:
    yfit.append(fit[0] * x**3 + fit[1] * x**2 + fit[2] * x + fit[3])
    
 


plt.style.use('fivethirtyeight')

plt.plot(xneg,yneg,'.',label='actual')
plt.plot(xfit,yfit,label='fitted')
plt.legend()
plt.xlabel("Spread")
plt.ylabel("Moneyline")
plt.title("Approximation of Spread to Moneyline Odds for NBA Games")

# %%
fit = np.polyfit(x,y,5)

# %%
xfit = np.linspace(-10,10,100)

yfit = []
for x in xfit:
    yfit.append(fit[0] * x**5 + fit[1] * x**4 + fit[2] * x**3 + fit[3] * x**2 + fit[4] *x + fit[5])

# %%
spread2ML.cs

# %%
plt.style.use('fivethirtyeight')

plt.plot(data['Spread'],data['ML'],'.',label='actual')
plt.plot(xfit,yfit,label='fitted')
plt.legend()
plt.xlabel("Spread")
plt.ylabel("Moneyline")
plt.title("Approximation of Spread to Moneyline Odds for NBA Games")

# %%
plt.plot()

# %%
def ML2Payout(ML,bet):
    """Convert Moneyline odds to a payout. 
    """
    
    if ML < 0: # - moneyline, 
        # PAYOUT = BET AMOUNT / (-1 *MONEYLINE ODDS / 100)

        payout = bet / (-1*ML/100)

    elif ML > 0:   #now for the underdog
        #PAYOUT = BET AMOUNT * ODDS / 100
        payout = (bet * ML) / 100

            
    else:
        payout = bet

    return payout

# %%
-y[0]

# %%
ML2Payout(-y[0],1)

# %%
data
# Out:
#     Spread    ML
# 0     -1.0  -115
# 1     -1.5  -121
# 2     -2.0  -132
# 3     -2.5  -143
# 4     -3.0  -156
# 5     -3.5  -170
# 6     -4.0  -184
# 7     -4.5  -199
# 8     -5.0  -222
# 9     -5.5  -247
# 10    -6.0  -276
# 11    -6.5  -309
# 12    -7.0  -349
# 13    -7.5  -397
# 14    -8.0  -458
# 15    -8.5  -536
# 16    -9.0  -656
# 17    -9.5  -832
# 18   -10.0 -1069
# 19     1.0  -104
# 20     1.5  -100
# 21     2.0   109
# 22     2.5   118
# 23     3.0   129
# 24     3.5   140
# 25     4.0   150
# 26     4.5   162
# 27     5.0   179
# 28     5.5   198
# 29     6.0   219
# 30     6.5   243
# 31     7.0   270
# 32     7.5   302
# 33     8.0   341
# 34     8.5   388
# 35     9.0   456
# 36     9.5   545
# 37    10.0   651
